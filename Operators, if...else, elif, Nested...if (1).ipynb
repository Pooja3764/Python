# %%
# print()-----Output function
# Can be used in 3 ways:
# Message: print("Message")
# Value  : print(Variable)
# Value with the message: print("Message",Variable)

# %%
# First Program: The sum of the two numbers  (started fm=29:50)
a=5
b=6
c=a+b
print("The sum is",c)
# Out:
# The sum is 11

# %%
#Program 2: Simple Interest
p=5000
r=6.5
t=6
si=p*r*t/100
print("the simple interest is", si)
# Out:
# the simple interest is 1950.0

# %%
# Program 3: Average of three numbers
a=50
b=70
c=30
Avg=(a+b+c)/3       # () important in above si ques. all were in multiply thatswhy
                              # that doesn't make any difference on that. PEMDAS are introduced here.
print("The average is", Avg)
# Out:
# The average is 50.0

# %%
#PEMDAS
#P------------Parenthysis
#E------------Exponent
#M------------Multiplication
#D--------------Division
#A----------------Addition
#S--------------Subtraction

# %%
# Program 4: Percentage of Marks
p=60
c=75
m=80
e=96
h=89
Sum=p+c+m+e+h
per=Sum*100/500
print("the percentage is",per)
# Out:
# the percentage is 80.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10**3
# Out:
# 1000

# %%
import math

# %%
# Find out the power
a=67
b=3
print(a**b)
print(pow(a,b))
print(math.pow(a,b))
# Out:
# 300763
# 300763
# 300763.0

# %%
n=67
x=math.sqrt(n)
print(x)
# Out:
# 8.18535277187245

# %%
# ASSIGNMENT OPERATOR
a=10  # Writing this just run, by this it will store 10 in a.

# %%
a+=3   # If we run this a+=3 again then output will become 16, as many times we will run this it will add in latest previous value of a.
a
# Out:
# 13

# %%
a-=3
a
# Out:
# 10

# %%
a*=3
a
# Out:
# 30

# %%
# COMPARISON OPERATOR
a=5
b=5
a==5
# Out:
# True

# %%
a==10
# Out:
# False

# %%
a>b
# Out:
# False

# %%
a>=b   # Rest do urself
# Out:
# True

# %%
# LOGICAL OPERATOR
True and True and True
# Out:
# True

# %%
True and True and False
# Out:
# False

# %%
False or True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
#-----------------------------------------------CLASS-2nd-------------------------------------

# %%
# First Program: The sum of the two numbers  (started fm=29:50)
a=int(input("enter the number"))
b=int(input("enter the number"))
c=a+b
print("The sum is",c)
# Out:
# enter the number5
# enter the number6
# The sum is 11

# %%
#Program 2: Simple Interest
p=int (input("enter the value of the principle"))
r=float (input("enter the value of the rate"))
t=int (input("enter the value of the time"))
si=p*r*t/100
print("the simple interest is", si)
# Out:
# enter the value of the principle5000
# enter the value of the rate6.5
# enter the value of the time6
# the simple interest is 1950.0

# %%
# Program 3: Average of three numbers
a=float(input("enter the number"))
b=float(input("enter the number"))
c=float(input("enter the number"))
Avg=(a+b+c)/3       # () important in above si ques. all were in multiply thatswhy
                              # that doesn't make any difference on that. PEMDAS are introduced here.
print("The average is", Avg)
# Out:
# enter the number50
# enter the number70
# enter the number30
# The average is 50.0

# %%
#PEMDAS
#P------------Parenthysis
#E------------Exponent
#M------------Multiplication
#D--------------Division
#A----------------Addition
#S--------------Subtraction

# %%
# Program 4: Percentage of Marks
p=float(input("Enter the number"))
c=float(input("Enter the number"))
m=float(input("Enter the number"))
e=float(input("Enter the number"))
h=float(input("Enter the number"))
Sum=p+c+m+e+h
per=Sum*100/500
print("the percentage is",per)
# Out:
# Enter the number60
# Enter the number75
# Enter the number80
# Enter the number6
# Enter the number88
# the percentage is 61.8

# %%
# Power and Sqrt

import math #sqrt,pow
n=float(input("enter the number"))
x=math.sqrt(n)
print("the result is",x)
# Out:
# enter the number625
# the result is 25.0

# %%
# Find Out the power
a=int(input("enter the value of the base "))
b=int(input("enter the value of the exponent "))
x=math.pow(a,b)
print("the res is",x)
# Out:
# enter the value of the base 25
# enter the value of the exponent 2
# the res is 625.0

# %%
# = ------------Assignment Operator

9# Swapping of two numbers
a=int(input("enter the number"))
b=int(input("enter the number"))
print("Before Swapping")
print("A=",a)
print("B",b)
temp=a
a=b
b=temp
print("After Swapping")
print("A=",a)
print("B=",b)
# Out:
# enter the number10
# enter the number20
# Before Swapping
# A= 10
# B 20
# After Swapping
# A= 20
# B= 10

# %%
# Swapping of two numbers
a=int(input("enter the number"))
b=int(input("enter the number"))
print("Before Swapping")
print("A=",a)
print("B",b)
a=a+b
b=a-b
a=a-b
print("After Swapping")
print("A=",a)
print("B=",b)
# Out:
# enter the number10
# enter the number30
# Before Swapping
# A= 10
# B 30
# After Swapping
# A= 30
# B= 10

# %%
# Swapping of two numbers (Method Of Only Python)
a=int(input("enter the number"))
b=int(input("enter the number"))
print("Before Swapping")
print("A=",a)
print("B",b)
a,b=b,a   # x,y=10,20
print("After Swapping")
print("A=",a)
print("B=",b)
# Out:
# enter the number25
# enter the number35
# Before Swapping
# A= 25
# B 35
# After Swapping
# A= 35
# B= 25

# %%
#COMPARISON OPERATORS          # These always returns True or False (Boolean Values) or called boolean signs ().
# ==
#<
#>
#<=
#>=
# Program based on the comparison Operator.
a=int(input("enter the number"))
b=int(input("enter the number"))
print(a==b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# enter the number10
# enter the number20
# False
# True
# False
# True

# %%
# Logical Operators
-----------------------
# and------------------all the conditions must be true.
# or--------------------any of the conditions is being true.

# Program based on logical operators.

a=int(input("enter the number"))
b=int(input("enter the number"))
c=int(input("enter the number"))

print(a>b and a>c)
print(b>a and b>c)
print(c>a and c>b)
# Out:
# enter the number30
# enter the number20
# enter the number10
# True
# False
# False

# %%
print(True or True or False)
# Out:
# True

# %%
print(False or False or False)
# Out:
# False

# %%
#------------------------------------CLASS-3rd------------------------------------------------------

# %%
n=int(input("enter the number"))
if n==10:
  print("You won")
# Out:
# enter the number10
# You won

# %%
# Program 2:
n=int(input("enter the number"))
if n>0:
  print("+ve number")
if n<0:
  print("-ve number")
if n==0:
  print("number is zero")
# Out:
# enter the number5
# +ve number

# %%
# if then else -----------------------# Means in this,if condition is true still there will be an output
                                        # And if condition is false still there will come an output (given by us in else block).

#Syntax:

# if condition:
   #statement
# else:
    #statement

# Program 1 : Check for even and odd -----------------------# % Modulus = Gives Remainder.

n=int(input("enter the number"))
if n%2==0:
 print("Even Number")
else:
 print("Odd Number")
# Out:
# enter the number7
# Odd Number

# %%
# Program 2 : Check Leap Year
year=int(input("enter the year"))
if year%4==0:
  print("leap year")
else:
  print("Non leap Year")
# Out:
# enter the year1999
# Non leap Year

# %%
# Program 3 : Vote eligibility
age= int(input("enter the age"))
if age>=18:
  print("Eligible to Vote")
else:
  print("Not eligible")
# Out:
# enter the age18
# Eligible to Vote

# %%
# if elif ladder form------------------- (In case of multiple conditions)


p=float(input("enter the marks"))
c=float(input("enter the marks"))
m=float(input("enter the marks"))
e=float(input("enter the marks"))
h=float(input("enter the marks"))
s=p+c+m+e+h
per=s*100/500
if per>=60:
  print("First")
elif per>=45:
  print("second")
elif per>=33:
  print("Third")
else:
  print("Fail")
# Out:
# enter the marks56
# enter the marks65
# enter the marks78
# enter the marks9
# enter the marks89
# second

# %%
day = int(input("Enter the value from 1-7 = "))
if day==1:
  print("Monday")
elif day==2:
  print("Tuesday")
elif day==3:
  print("Wednesday")
elif day==4:
  print("Thursday")
elif day==5:
  print("Friday")
elif day==6:
  print("Saturday")
elif day==7:
  print("Sunday")
else:
  print("Invalid")
# Out:
# Enter the value from 1-7 = 7
# Sunday

# %%
# Logical Operators-----------------------------------# and = all the conditions associated with 'and' must be true for the output = true
                                                      # or =  any of the condition associated with 'or'must be true for the output = true

a=int(input("enter the number"))
b=int(input("enter the number"))
c=int(input("enter the number"))
if a>b and a>c:
  print("A is Greater")
elif b>a and b>c:
  print("B is Greater")
else:
  print("Cis Greater")
# Out:
# enter the number23
# enter the number26
# enter the number30
# Cis Greater

# %%
# Check Vowel or Consonant
# Here, it has 2-3 variant of doing this program, will cover further them too.
ch=input("enter an alphabet ")
if ch=='a' or ch=='e' or ch=='i' or ch=='o' or ch=='u':
  print("vowel")
elif ch=='A' or ch=='E' or ch=='I' or ch=='O' or ch=='U':
  print("vowel")
else:
  print("Consonant")
# Out:
# enter an alphabet a
# vowel

# %%
# Type:2
# Check Vowel Or consonant
ch=input("enter an alphabet ")
if ch in ['a','e','i','o','u','A','E','I','O','U']:                   # in = Here, 'in' is a membership operator.
 print("Vowel")
else:
  print("Consonant")
# Out:
# enter an alphabet a
# Vowel

# %%
# Type:3
# Check vowel or consonant
ch=input("enter an alphabet ")
if ch in "aeiouAEIOU":      # Here, it is a string, as string is also a container.Variable is also
                            # a container but that store a single value.
 print("Vowel")
else:
  print("Consonant")
# Out:
# enter an alphabet e
# Vowel

# %%
ch=input("enter a color code like \n r for red \n g for green \n y for yellow \n = ")
if ch=='r' or ch=='R':
  print("Stop")
elif ch=='g' or ch=='G':
  print("Move forward")
elif ch=='y' or ch=='Y':
  print("Get Ready")
else:
  print("Pay chalaan")
# Out:
# enter a color code like
#  r for red
#  g for green
#  y for yellow
#  = y
# Get Ready

# %%
# Mini Calculator
a=int(input("enter the number"))
b=int(input("enter the number"))
print("1.Add")
print("2.Sub")
print("3.Mul")
print("4.Div")
choice=int(input("enter the choice from above"))
if choice==1:
  print("Addition is",a+b)
elif choice==2:
  print("Subtraction is",a-b)
elif choice==3:
  print("Multiplication is",a*b)
elif choice==4:
  print("Division is",a/b)
else:
  print("Invalid choice")
# Out:
# enter the number5
# enter the number6
# 1.Add
# 2.Sub
# 3.Mul
# 4.Div
# enter the choice from above3
# Multiplication is 30
